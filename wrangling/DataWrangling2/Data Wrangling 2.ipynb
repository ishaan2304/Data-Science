# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = {
    "Student_ID": range(1, 21),
    "Age": [20,21,18,19,20, np.nan, 17, 18, 19, 20, 21, 15, 16, 17, 23,20,18, 19, 17, 15],
    "Name": ["Bhavesh","Shreyash","Shritej","Shrawni","Kartiik","Ria","sam","Mee","Mike","Rim","Ram","Shrawni","Kartiik","Ria","sam","Mee","Mike","Rim","Shrawni","Kartiik"],
    "Gender": ["Male", "Male", "Male", "Female", "Male", "Female", "Male", "Female", "Male", "Female", "Male", "Female", "Male", "Female", "Male", "Female", "Male", "Female", "Male", "Female"],
    "Math_Score": [85, 90, 78, 92, 85, 88, 95, 60, 55, 100, 45, np.nan, 91, 84, 88, 86, 99, 52, 70, 65],
    "Reading_Score": [88, 85, 80, 66, 89, 90, 86, np.nan, 60, 98, 50, 85, 87, 88, 84, 82, 95, 45, 75, 65],
    "Writing_Score": [80, 82, 78, 85, 88, 85, 90, 86, 55, 95, 48, 83, 85, 88, 84, 82, 99,np.nan, 70, 65],
}
data
# Out:
# {'Student_ID': range(1, 21),
#  'Age': [20,
#   21,
#   18,
#   19,
#   20,
#   nan,
#   17,
#   18,
#   19,
#   20,
#   21,
#   15,
#   16,
#   17,
#   23,
#   20,
#   18,
#   19,
#   17,
#   15],
#  'Name': ['Bhavesh',
#   'Shreyash',
#   'Shritej',
#   'Shrawni',
#   'Kartiik',
#   'Ria',
#   'sam',
#   'Mee',
#   'Mike',
#   'Rim',
#   'Ram',
#   'Shrawni',
#   'Kartiik',
#   'Ria',
#   'sam',
#   'Mee',
#   'Mike',
#   'Rim',
#   'Shrawni',
#   'Kartiik'],
#  'Gender': ['Male',
#   'Male',
#   'Male',
#   'Female',
#   'Male',
#   'Female',
#   'Male',
#   'Female',
#   'Male',
#   'Female',
#   'Male',
#   'Female',
#   'Male',
#   'Female',
#   'Male',
#   'Female',
#   'Male',
#   'Female',
#   'Male',
#   'Female'],
#  'Math_Score': [85,
#   90,
#   78,
#   92,
#   85,
#   88,
#   95,
#   60,
#   55,
#   100,
#   45,
#   nan,
#   91,
#   84,
#   88,
#   86,
#   99,
#   52,
#   70,
#   65],
#  'Reading_Score': [88,
#   85,
#   80,
#   66,
#   89,
#   90,
#   86,
#   nan,
# ...

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#     Student_ID   Age      Name  Gender  Math_Score  Reading_Score  \
# 0            1  20.0   Bhavesh    Male        85.0           88.0
# 1            2  21.0  Shreyash    Male        90.0           85.0
# 2            3  18.0   Shritej    Male        78.0           80.0
# 3            4  19.0   Shrawni  Female        92.0           66.0
# 4            5  20.0   Kartiik    Male        85.0           89.0
# 5            6   NaN       Ria  Female        88.0           90.0
# 6            7  17.0       sam    Male        95.0           86.0
# 7            8  18.0       Mee  Female        60.0            NaN
# 8            9  19.0      Mike    Male        55.0           60.0
# 9           10  20.0       Rim  Female       100.0           98.0
# 10          11  21.0       Ram    Male        45.0           50.0
# 11          12  15.0   Shrawni  Female         NaN           85.0
# 12          13  16.0   Kartiik    Male        91.0           87.0
# ...

# %%
df.isnull().sum()
# Out:
# Student_ID       0
# Age              1
# Name             0
# Gender           0
# Math_Score       1
# Reading_Score    1
# Writing_Score    1
# dtype: int64

# %%
df['Age'] = df['Age'].fillna(df['Age'].median())
df['Math_Score'] = df['Math_Score'].fillna(df['Math_Score'].mean())
df['Reading_Score'] = df['Reading_Score'].fillna(df['Reading_Score'].mean())
df['Writing_Score'] = df['Writing_Score'].fillna(df['Writing_Score'].mean())

# %%
df
# Out:
#     Student_ID   Age      Name  Gender  Math_Score  Reading_Score  \
# 0            1  20.0   Bhavesh    Male   85.000000      88.000000
# 1            2  21.0  Shreyash    Male   90.000000      85.000000
# 2            3  18.0   Shritej    Male   78.000000      80.000000
# 3            4  19.0   Shrawni  Female   92.000000      66.000000
# 4            5  20.0   Kartiik    Male   85.000000      89.000000
# 5            6  19.0       Ria  Female   88.000000      90.000000
# 6            7  17.0       sam    Male   95.000000      86.000000
# 7            8  18.0       Mee  Female   60.000000      78.842105
# 8            9  19.0      Mike    Male   55.000000      60.000000
# 9           10  20.0       Rim  Female  100.000000      98.000000
# 10          11  21.0       Ram    Male   45.000000      50.000000
# 11          12  15.0   Shrawni  Female   79.368421      85.000000
# 12          13  16.0   Kartiik    Male   91.000000      87.000000
# ...

# %%
df.isnull().sum()
# Out:
# Student_ID       0
# Age              0
# Name             0
# Gender           0
# Math_Score       0
# Reading_Score    0
# Writing_Score    0
# dtype: int64

# %%
for column in ['Age', 'Math_Score', 'Reading_Score', 'Writing_Score']:
    sns.boxplot(df[column])
    plt.title(f"Boxplot of {column}")
    plt.show()

# %%
def handle_outliers(column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df[column] = np.where(df[column] < lower_bound, lower_bound, df[column])
    df[column] = np.where(df[column] > upper_bound, upper_bound, df[column])

for column in ['Age', 'Math_Score', 'Reading_Score', 'Writing_Score']:
    handle_outliers(column)

print("\nDataset after handling outliers:")
print(df)
# Out:
# Dataset after handling outliers:
#     Student_ID   Age      Name  Gender  Math_Score  Reading_Score  \
# 0            1  20.0   Bhavesh    Male   85.000000      88.000000
# 1            2  21.0  Shreyash    Male   90.000000      85.000000
# 2            3  18.0   Shritej    Male   78.000000      80.000000
# 3            4  19.0   Shrawni  Female   92.000000      66.000000
# 4            5  20.0   Kartiik    Male   85.000000      89.000000
# 5            6  19.0       Ria  Female   88.000000      90.000000
# 6            7  17.0       sam    Male   95.000000      86.000000
# 7            8  18.0       Mee  Female   60.000000      78.842105
# 8            9  19.0      Mike    Male   55.000000      60.000000
# 9           10  20.0       Rim  Female  100.000000      98.000000
# 10          11  21.0       Ram    Male   45.000000      50.000000
# 11          12  15.0   Shrawni  Female   79.368421      85.000000
# 12          13  16.0   Kartiik    Male   91.000000      87.000000
# ...

# %%
df
# Out:
#     Student_ID   Age      Name  Gender  Math_Score  Reading_Score  \
# 0            1  20.0   Bhavesh    Male   85.000000      88.000000
# 1            2  21.0  Shreyash    Male   90.000000      85.000000
# 2            3  18.0   Shritej    Male   78.000000      80.000000
# 3            4  19.0   Shrawni  Female   92.000000      66.000000
# 4            5  20.0   Kartiik    Male   85.000000      89.000000
# 5            6  19.0       Ria  Female   88.000000      90.000000
# 6            7  17.0       sam    Male   95.000000      86.000000
# 7            8  18.0       Mee  Female   60.000000      78.842105
# 8            9  19.0      Mike    Male   55.000000      60.000000
# 9           10  20.0       Rim  Female  100.000000      98.000000
# 10          11  21.0       Ram    Male   45.000000      50.000000
# 11          12  15.0   Shrawni  Female   79.368421      85.000000
# 12          13  16.0   Kartiik    Male   91.000000      87.000000
# ...

# %%
for column in ['Age', 'Math_Score', 'Reading_Score', 'Writing_Score']:
    sns.boxplot(df[column])
    plt.title(f"Boxplot of {column}")
    plt.show()

# %%
print("\nBefore Transformation:")
print(df['Math_Score'].describe())
sns.histplot(df['Math_Score'], kde=True)
plt.title("Math_Score Distribution Before Transformation")
plt.show()

df['Math_Score_Log'] = np.log1p(df['Math_Score'])

print("\nAfter Transformation:")
print(df['Math_Score_Log'].describe())
sns.histplot(df['Math_Score_Log'], kde=True)
plt.title("Math_Score Distribution After Transformation")
plt.show()
# Out:
# Before Transformation:
# count     20.000000
# mean      79.368421
# std       16.118673
# min       45.000000
# 25%       68.750000
# 50%       85.000000
# 75%       90.250000
# max      100.000000
# Name: Math_Score, dtype: float64
# After Transformation:
# count    20.000000
# mean      4.364399
# std       0.224990
# min       3.828641
# 25%       4.244424
# 50%       4.454347
# 75%       4.513592
# max       4.615121
# Name: Math_Score_Log, dtype: float64

# %%
df
# Out:
#     Student_ID   Age      Name  Gender  Math_Score  Reading_Score  \
# 0            1  20.0   Bhavesh    Male   85.000000      88.000000
# 1            2  21.0  Shreyash    Male   90.000000      85.000000
# 2            3  18.0   Shritej    Male   78.000000      80.000000
# 3            4  19.0   Shrawni  Female   92.000000      66.000000
# 4            5  20.0   Kartiik    Male   85.000000      89.000000
# 5            6  19.0       Ria  Female   88.000000      90.000000
# 6            7  17.0       sam    Male   95.000000      86.000000
# 7            8  18.0       Mee  Female   60.000000      78.842105
# 8            9  19.0      Mike    Male   55.000000      60.000000
# 9           10  20.0       Rim  Female  100.000000      98.000000
# 10          11  21.0       Ram    Male   45.000000      50.000000
# 11          12  15.0   Shrawni  Female   79.368421      85.000000
# 12          13  16.0   Kartiik    Male   91.000000      87.000000
# ...
